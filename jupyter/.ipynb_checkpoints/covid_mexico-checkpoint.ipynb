# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('text', usetex=True)
rc('text.latex', preamble=r'\usepackage{cmbright}')
rc('font', **{'family': 'sans-serif', 'sans-serif': ['Helvetica']})

# %matplotlib inline

# This enables SVG graphics inline. 
# %config InlineBackend.figure_formats = {'png', 'retina'}

# JB's favorite Seaborn settings for notebooks
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'DFDFE5'}
sns.set_context('notebook', rc=rc)
sns.set_style("dark")

mpl.rcParams['xtick.labelsize'] = 16 
mpl.rcParams['ytick.labelsize'] = 16 
mpl.rcParams['legend.fontsize'] = 14

# %%
from covidmx import CovidMX

latest_published_data = CovidMX(source='Serendipia').get_data()
# Out:
# Reading data
# Searching last date available for confirmed...
# Last date available: 16-04-2020
# Searching last date available for suspects...
# Last date available: 16-04-2020
# Cleaning data

# %%
latest_published_data
# Out:
#        edad            estado fecha_busqueda fecha_de_inicio_de_sintomas  \
# 0      75.0            MÉXICO     2020-04-16                  2020-03-28
# 1      22.0        TAMAULIPAS     2020-04-16                  2020-04-04
# 2      40.0  CIUDAD DE MÉXICO     2020-04-16                  2020-03-17
# 3      29.0  CIUDAD DE MÉXICO     2020-04-16                  2020-03-26
# 4      61.0          GUERRERO     2020-04-16                  2020-04-06
# ...     ...               ...            ...                         ...
# 18632  30.0           NAYARIT     2020-04-16                  2020-04-06
# 18633  41.0        NUEVO LEÓN     2020-04-16                  2020-03-30
# 18634  49.0           YUCATÁN     2020-04-16                  2020-04-09
# 18635  35.0            PUEBLA     2020-04-16                  2020-03-23
# 18636  18.0           TABASCO     2020-04-16                  2020-03-21
#
#       identificacion n_caso       sexo
# 0         Confirmado      1   FEMENINO
# 1         Confirmado      2  MASCULINO
# 2         Confirmado      3  MASCULINO
# 3         Confirmado      4   FEMENINO
# 4         Confirmado      5   FEMENINO
# ...              ...    ...        ...
# 18632     Sospechoso  12336  MASCULINO
# 18633     Sospechoso  12337   FEMENINO
# 18634     Sospechoso  12338   FEMENINO
# 18635     Sospechoso  12339  MASCULINO
# 18636     Sospechoso  12340   FEMENINO
#
# [18637 rows x 7 columns]
